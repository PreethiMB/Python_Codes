# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('D:/Landsat_Indices/Analysis/ControlNorth/ZS_CN.csv')

# %%
fig = plt.figure()
ax = plt.axes()
plt.grid(True, color='green', alpha=0.3, linestyle='-.', linewidth=2)

# %%
columns = ['Year','Median', 'Mean']
df = pd.read_csv('D:/Landsat_Indices/Analysis/NewWells1/ZS_NW1.csv', usecols=columns,
    )

# %%
df.head()
# Out:
#    Year    Median      Mean
# 0  2013  0.022721  0.032267
# 1  2014  0.036914  0.041379
# 2  2015  0.068404  0.073406
# 3  2016  0.026597  0.034077
# 4  2017  0.032726  0.039515

# %%
df.plot(x='Year', color =['blue', 'red'], marker='.')
plt.ylim(ymax = 0.12, ymin = 0, 0.01)
plt.grid(True, color='b', alpha=0.3, linestyle='-.', linewidth=2 )
plt.legend()
plt.show()
# Out:
#   Cell In[111], line 2
#     plt.ylim(ymax = 0.12, ymin = 0, 0.01)
#                                         ^
# SyntaxError: positional argument follows keyword argument

# %%
y = np.arange(0, 0.14, 0.2)
df.plot(x='Year', y = 'Median', color ='blue', marker='.')
plt.grid(True, color='b', alpha=0.3, linestyle='-.', linewidth=2 )
plt.legend()
plt.savefig('D:/Landsat_Indices/Analysis/Thompson/ZS_Med_Th2.png')
plt.show()

# %%
columns = ['Year','Median', 'Mean']
df = pd.read_csv('D:/Landsat_Indices/Analysis/American/ZS_AM.csv', usecols=columns,
    )

# %%
df.plot(x='Year', color =['blue', 'red'], marker='.')
plt.ylim(ymax = 0.12, ymin = 0)
plt.grid(True, color='b', alpha=0.3, linestyle='-.', linewidth=2 )
plt.savefig('D:/Landsat_Indices/Analysis/NewWells1/ZS_MM_NW1a.png')
plt.legend()
plt.show()

# %%
columns = ['Year','Median', 'Mean']
df = pd.read_csv('D:/Landsat_Indices/Analysis/ControlNorth/ZS_CN.csv', usecols=columns,
    )

# %%
df.plot(x='Year', color =['blue', 'red'], marker='.')
plt.ylim(ymax = 0.12, ymin = 0)
plt.grid(True, color='b', alpha=0.3, linestyle='-.', linewidth=2 )
plt.legend()
plt.show()
