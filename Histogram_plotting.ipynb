# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pd.read_csv('Z:\\2023\\Spring2023\\Landsat_final\\NDVI_Max_clip_for_compare\\Points\\Th_2022MAX.csv')
df.head(1)
# Out:
#    OID_  VALUE         X          Y  NDVI_2022_Th_Clip
# 0     1      0  354240.0  4763400.0           0.311381

# %%
ax = sns.histplot(data=df, x='NDVI_2022_Th_Clip', kde=False, color='lightblue', bins=35)
sns.kdeplot(data=df, x='NDVI_2022_Th_Clip', color='blue')
#ax.set_xlim(0,0.5)
#plt.xlim(0.05,0.55, 0.05)
#plt.ylim(0,100,20)
plt.xticks(np.arange(0.05, 0.75, 0.05))
plt.yticks(np.arange(0,40,5))
#plt.xticks(rotation=60)
plt.axvline(x=df.NDVI_2022_Th_Clip.mean(),
            color='red')

plt.savefig('Z:\\2023\\Spring2023\\Landsat_final\\NDVI_Max_clip_for_compare\\Points\\Comparable_graphs\\Th_Max2022.png', dpi=600)
